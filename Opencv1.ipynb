# %%
import numpy as np
import cv2 as cv2  # import opencv
from skimage import io

# %%
img=io.imread('https://ep01.epimg.net/elpais/imagenes/2019/04/04/ciencia/1554365324_392642_1554369251_noticia_normal.jpg')

# %%
print(img.shape)
# Out:
# (559, 980, 3)

# %%
io.imshow(img)

# %%
img1=io.imread('https://static.theprint.in/wp-content/uploads/2020/11/EilxqtGWkAgg3vL-e1605948236762-696x392.jpeg')

# %%
io.imshow(img1)

# %%
img1.shape
# Out:
# (392, 696, 3)

# %%
img=cv2.resize(img,(696,392))

# %%
img2=cv2.addWeighted(img,0.2,img1,0.7,-50)

# %%
io.imshow(img2)
